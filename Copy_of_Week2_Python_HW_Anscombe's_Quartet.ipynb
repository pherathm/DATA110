# %% [markdown]
# <a href="https://colab.research.google.com/github/pherathm/DATA110/blob/main/Copy_of_Week2_Python_HW_Anscombe's_Quartet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1: Import Necessary Packages
#
# Before we begin, we need to import the necessary Python libraries for plotting and performing the regression. We'll use:
#
# - `matplotlib.pyplot` for creating the graph
# - `numpy` for numerical operations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 2: Anscombe's Quartet Dataset
#
# This dataset is known as **Anscombe's Quartet**, created by statistician Francis Anscombe to illustrate the importance of visualizing data. Despite having nearly identical statistical properties (e.g., mean, variance, correlation, and linear regression), each dataset tells a very different story when graphed.
#
# - **x**: The independent variable, common across three datasets.
# - **y1, y2, y3**: Three different dependent variables associated with the same `x` values.
# - **x4, y4**: A special case where most of the `x` values are identical, with one outlier.
#
# #### Anscombe's Quartet:
#
# `

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')

# %% [markdown]
# ### Your Task:
#
# Perform the same linear regression process for the following datasets: y2, y3, and y4.
# Modify the code to calculate and plot the regression lines for each of these datasets.
# Use distinct colors for each plot and appropriately label the axes (y2, y3, etc.).
# Discuss any differences you observe when comparing the results across all datasets.

# %%
# Your Code need to be here for x and y2

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y2, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y2)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
# Your Code need to be here for x and y3

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y3, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y3)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
# Your code need to be here for x and y4

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y4)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %%
# Your code need to be here for x4 and y4

# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x4, y4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x4, y4)
plt.plot(x, regression_line,color='red')
plt.xlabel('x4')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %% [markdown]
# ### Reflection Question:
#
# After visualizing the linear regression for all four datasets in Anscombe's Quartet, reflect on the following:
#
# #### What is your reflection?
# -** How do the datasets visually differ despite having similar summary statistics?**
#
# Even though the five datasets have the same summary statistics, their visual patterns are quite different.
#
# (x, y1) dataset follows a positive simple linear relationship. Although (x, y2) graph shows a linear relationship (positive), this regression line doesn't accurately represent the pattern of the data. A curved relationship might be more appropriate for this data set. (x, y3) dataset contains a strong outlier that changes the linear fit, even though most points are in a linear regression (positive). This outlier influences the shape of the regression line (slope and the y intercept). (x, y4) data set shows a negative linear relationship. Most of the data points are closely grouped around a central value, but the presence of a strong outlier significantly skews the visual representation of the dataset. In the graph of (x4, y4), outlier at x4=19 greatly skews the regression line to a positive linear regression line. Most data points are aligned at x4=8, but the extreme outlier strongly affects to the slope of the line.
#
# **- How did the outlier in the `x4, y4` dataset affect the regression line compared to the other datasets?**
#
#
# When compared with the other datasets, the regression line here doesn't fit with the most of of the data points due to a presence of an outlier. Therefore, regression line does not represent the actual relationship between x4 and y4.
#
#
# **- Why is it important to visualize data in addition to calculating summary statistics?**
#
# Visualizing data is really important because it helps to identify outliers and their impact, which summary statistics does not represent. Eventhough the summary statistics such as the mean or correlation shows a linear relationships, visual representations can show non-linear patterns. For example, the summary statistics of the(x4,y4) dataset may suggest a strong relationship,but the plot shows that the outlier skews the true pattern of the data set. This indecates the importance of using visualizations to get deeper and more accurate understanding of data.
#
#
# **Please provide your insights and discuss the importance of data visualization in understanding relationships between variables.**
#
# Data visualization can reveal outliers, non-linear relationships, and other patterns that simple statistics does not represent. Anscombe’s Quartet shows that different datasets having similar summary statistics while having different visual representations. It highlights the importance of data visualization besides numerical summaries.
